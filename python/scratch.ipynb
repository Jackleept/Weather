# %% [markdown]
# Initial API test

# %%
import requests
import sqlite3
import time


lat = '51.5072'
lon = '0.1276'
now = '1708622726'#int(time.time())
from key import key

link = f'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat={lat}&lon={lon}&dt={now}&appid={key}&units=metric'
conn = sqlite3.connect('weather.db')
response = requests.get(link)
response.text
# Out:
# '{"lat":51.5072,"lon":0.1276,"timezone":"Europe/London","timezone_offset":0,"data":[{"dt":1708622726,"sunrise":1708585263,"sunset":1708622726,"temp":4.83,"feels_like":-0.57,"pressure":981,"humidity":90,"dew_point":3.33,"clouds":100,"visibility":10000,"wind_speed":9.77,"wind_deg":280,"weather":[{"id":501,"main":"Rain","description":"moderate rain","icon":"10n"}],"rain":{"1h":1.78}}]}'

# %%
data = response.json()
data
# Out:
# {'lat': 51.5072,
#  'lon': 0.1276,
#  'timezone': 'Europe/London',
#  'timezone_offset': 0,
#  'data': [{'dt': 1708622726,
#    'sunrise': 1708585263,
#    'sunset': 1708622726,
#    'temp': 4.83,
#    'feels_like': -0.57,
#    'pressure': 981,
#    'humidity': 90,
#    'dew_point': 3.33,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 9.77,
#    'wind_deg': 280,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'rain': {'1h': 1.78}}]}

# %% [markdown]
# Cleaning the response data
#
# Initially I didn't realise that the 'rain' and 'snow' data were given as dict because they are not always included.
#
# This caused an SQLite dict error later, so I had to add in a cleaning step for this.

# %%
d1 = {'lat': data['lat'], 'lon': data['lon'], 'timezone': data['timezone'], 'timezone_offset': data['timezone_offset']}

for i in data['data']:
    d1.update(i)

for i in d1['weather']:
    d1.update(i)

d1.pop('weather')

data = d1

#if 'rain' in data.keys():
    #data['rain'] = list(data['rain'].values())[0]

if 'rain' in data.keys():
    data['rain'] = [*data['rain'].values()][0]

if 'snow' in data.keys():
    data['snow'] = [*data['snow'].values()][0]

data
# Out:
# {'lat': 51.5072,
#  'lon': 0.1276,
#  'timezone': 'Europe/London',
#  'timezone_offset': 0,
#  'dt': 1708622726,
#  'sunrise': 1708585263,
#  'sunset': 1708622726,
#  'temp': 4.83,
#  'feels_like': -0.57,
#  'pressure': 981,
#  'humidity': 90,
#  'dew_point': 3.33,
#  'uvi': 0,
#  'clouds': 100,
#  'visibility': 10000,
#  'wind_speed': 9.77,
#  'wind_deg': 280,
#  'rain': 1,
#  'id': 500,
#  'main': 'Rain',
#  'description': 'light rain',
#  'icon': '10n'}

# %% [markdown]
# To avoid SQL insertion errors due to lack of data values, I added a step to include placeholders.
#
# This is necessary because the API does not send keys with null values.

# %%
all_api_keys = ['lat', 'lon', 'timezone', 'timezone_offset', 'dt', 
                'sunrise', 'sunset', 'temp', 'feels_like', 'pressure', 
                'humidity', 'dew_point', 'uvi', 'clouds', 'visibility', 
                'wind_speed', 'wind_deg', 'wind_gust', 'id', 'main', 
                'description', 'icon', 'rain', 'snow']

for i in all_api_keys:
    if i not in data.keys():
        i = {i: 'N/A'}
        data.update(i)

data
# Out:
# {'lat': 51.5072,
#  'lon': 0.1276,
#  'timezone': 'Europe/London',
#  'timezone_offset': 0,
#  'dt': 1708622726,
#  'sunrise': 1708585263,
#  'sunset': 1708622726,
#  'temp': 4.83,
#  'feels_like': -0.57,
#  'pressure': 981,
#  'humidity': 90,
#  'dew_point': 3.33,
#  'uvi': 0,
#  'clouds': 100,
#  'visibility': 10000,
#  'wind_speed': 9.77,
#  'wind_deg': 280,
#  'rain': 1,
#  'id': 500,
#  'main': 'Rain',
#  'description': 'light rain',
#  'icon': '10n',
#  'wind_gust': 'N/A',
#  'snow': 'N/A'}

# %% [markdown]
# Placing all cleaning code into a function

# %%
def clean_data(data):

    d1 = {'lat': data['lat'], 'lon': data['lon'], 'timezone': data['timezone'], 'timezone_offset': data['timezone_offset']}

    for i in data['data']:
        d1.update(i)

    for i in d1['weather']:
        d1.update(i)

    d1.pop('weather')

    data = d1

    if 'rain' in data.keys():
        data['rain'] = [*data['rain'].values()][0]

    if 'snow' in data.keys():
        data['snow'] = [*data['snow'].values()][0]

    all_api_keys = ['lat', 'lon', 'timezone', 'timezone_offset', 'dt', 
                'sunrise', 'sunset', 'temp', 'feels_like', 'pressure', 
                'humidity', 'dew_point', 'uvi', 'clouds', 'visibility', 
                'wind_speed', 'wind_deg', 'wind_gust', 'id', 'main', 
                'description', 'icon', 'rain', 'snow']
    
    for i in all_api_keys:
        if i not in data.keys():
            i = {i: 'N/A'}
            data.update(i)

    return data

data = clean_data(data)

data

# %% [markdown]
# Creating SQL table and loading values

# %%
conn = sqlite3.connect('weather.db')
cursor = conn.cursor()

cursor.executescript('''

        CREATE TABLE IF NOT EXISTS weather (
                    lat,
                    lon,
                    timezone,
                    timezone_offset,
                    date,
                    sunrise,
                    sunset,
                    temp,
                    feels_like,
                    pressure,
                    humidity,
                    dew_point,
                    uvi,
                    clouds,
                    visibility,
                    wind_speed,
                    wind_gust,
                    wind_deg,
                    weather_id,
                    main,
                    description,
                    icon,
                    rain,
                    snow     
        )
    ''')

cursor.execute('''INSERT INTO weather VALUES (:lat, :lon, :timezone, :timezone_offset,
               :dt, :sunrise, :sunset, :temp, :feels_like, :pressure, :humidity,
               :dew_point, :uvi, :clouds, :visibility, :wind_speed, :wind_gust, :wind_deg,
               :id, :main, :description, :icon, :rain, :snow)''', data
               )

conn.commit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 conn = sqlite3.connect('weather.db')
#       2 cursor = conn.cursor()
#       4 cursor.executescript('''
#       5
#       6         CREATE TABLE IF NOT EXISTS weather (
#    (...)
#      31         )
#      32     ''')
#
# NameError: name 'sqlite3' is not defined

# %% [markdown]
# Quick test to see that everything is working so far

# %%
import pandas as pd

df = pd.read_sql_query('''SELECT * FROM weather''', conn)
df
# Out:
#        lat     lon       timezone  timezone_offset        date     sunrise  \
# 0  51.5072  0.1276  Europe/London                0  1708622726  1708585263
#
#        sunset  temp  feels_like  pressure  ...  visibility  wind_speed  \
# 0  1708622726  4.83       -0.57       981  ...       10000        9.77
#
#    wind_gust  wind_deg  weather_id  main description  icon  rain snow
# 0        N/A       280         500  Rain  light rain   10n     1  N/A
#
# [1 rows x 24 columns]

# %% [markdown]
# Creating drop table function

# %%
def drop_table():

    cursor.executescript('''

        DROP TABLE IF EXISTS weather

    ''')

    conn.commit()

drop_table()

# %% [markdown]
# Adding a last executed file so the database can be updated efficiently

# %%
def last_executed():

        try:
                with open('last_executed.txt') as f:
                        last_execution_date = int(f.read())
        except FileNotFoundError:
                last_execution_date = int(time.time())

        return last_execution_date

last_execution_date = last_executed()

# %%
def update_executed():
    with open('last_executed.txt', 'w') as f:
        f.write(str(int(time.time())))

# %% [markdown]
# Creating function to build a list of links for every hour since the code was last executed

# %%
def get_links():
    
    if last_execution_date // 86400 ==  time.time() // 86400:
        return []

    links = []

    def build_link(date):
        lat = '51.5072'
        lon = '0.1276'
        from python.key import key
        link = f'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat={lat}&lon={lon}&dt={date}&appid={key}&units=metric'
        links.append(link)

    nearest_hour = int(time.time() - time.time() % 3600)
    nearest_hour_old = last_execution_date - last_execution_date % 3600

    for x in range(nearest_hour_old+3600, nearest_hour, 3600):
        build_link(x)
    
    return links

get_links()
# Out:
# ['https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705345200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705348800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705352400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705356000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705359600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705363200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705366800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705370400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705374000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705377600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705381200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705384800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705388400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705392000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705395600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705399200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705402800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705406400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705410000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705413600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705417200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705420800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705424400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705428000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705431600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705435200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705438800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705442400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705446000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705449600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705453200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705456800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705460400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705464000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705467600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705471200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705474800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705478400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705482000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705485600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705489200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705492800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705496400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705500000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705503600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705507200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705510800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705514400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705518000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705521600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705525200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705528800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705532400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705536000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705539600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705543200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705546800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705550400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705554000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705557600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705561200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705564800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705568400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705572000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705575600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705579200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705582800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705586400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705590000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705593600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705597200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705600800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705604400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705608000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705611600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705615200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705618800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705622400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705626000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705629600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705633200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705636800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705640400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705644000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705647600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705651200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705654800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705658400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705662000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705665600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705669200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705672800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705676400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705680000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705683600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705687200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705690800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705694400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705698000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705701600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705705200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705708800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705712400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705716000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705719600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705723200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705726800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705730400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705734000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705737600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705741200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705744800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705748400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705752000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705755600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705759200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705762800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705766400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705770000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705773600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705777200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705780800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705784400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705788000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705791600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705795200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705798800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705802400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705806000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705809600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705813200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705816800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705820400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705824000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705827600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705831200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705834800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705838400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705842000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705845600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705849200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705852800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705856400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705860000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705863600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705867200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705870800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705874400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705878000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705881600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705885200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705888800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705892400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705896000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705899600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705903200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705906800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705910400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705914000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705917600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705921200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705924800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705928400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705932000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705935600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705939200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705942800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705946400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705950000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705953600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705957200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705960800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705964400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705968000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705971600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705975200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705978800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705982400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705986000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705989600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705993200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1705996800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706000400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706004000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706007600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706011200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706014800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706018400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706022000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706025600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706029200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706032800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706036400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706040000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706043600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706047200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706050800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706054400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706058000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706061600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706065200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706068800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706072400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706076000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706079600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706083200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706086800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706090400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706094000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706097600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706101200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706104800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706108400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706112000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706115600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706119200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706122800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706126400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706130000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706133600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706137200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706140800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706144400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706148000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706151600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706155200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706158800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706162400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706166000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706169600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706173200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706176800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706180400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706184000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706187600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706191200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706194800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706198400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706202000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706205600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706209200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706212800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706216400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706220000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706223600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706227200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706230800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706234400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706238000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706241600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706245200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706248800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706252400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706256000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706259600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706263200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706266800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706270400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706274000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706277600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706281200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706284800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706288400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706292000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706295600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706299200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706302800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706306400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706310000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706313600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706317200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706320800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706324400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706328000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706331600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706335200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706338800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706342400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706346000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706349600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706353200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706356800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706360400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706364000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706367600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706371200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706374800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706378400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706382000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706385600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706389200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706392800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706396400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706400000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706403600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706407200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706410800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706414400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706418000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706421600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706425200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706428800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706432400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706436000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706439600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706443200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706446800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706450400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706454000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706457600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706461200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706464800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1706468400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
# ...
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708387200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708390800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708394400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708398000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708401600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708405200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708408800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708412400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708416000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708419600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708423200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708426800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708430400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708434000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708437600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708441200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708444800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708448400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708452000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708455600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708459200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708462800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708466400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708470000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708473600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708477200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708480800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708484400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708488000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708491600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708495200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708498800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708502400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708506000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708509600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708513200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708516800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708520400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708524000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708527600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708531200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708534800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708538400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708542000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708545600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708549200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708552800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708556400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708560000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708563600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708567200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708570800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708574400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708578000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708581600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708585200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708588800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708592400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708596000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708599600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708603200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708606800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708610400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708614000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708617600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708621200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708624800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708628400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708632000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708635600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708639200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708642800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708646400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708650000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708653600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708657200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708660800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708664400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708668000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708671600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708675200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708678800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708682400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708686000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708689600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708693200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708696800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708700400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708704000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708707600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708711200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708714800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708718400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708722000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708725600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708729200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708732800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708736400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708740000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708743600&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708747200&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708750800&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708754400&appid=e276140c3e33a20f93a7c86e198a285e&units=metric',
#  'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=51.5072&lon=0.1276&dt=1708758000&appid=e276140c3e33a20f93a7c86e198a285e&units=metric']

# %% [markdown]
# Putting all the relevant code into a function for extracting and loading the data

# %%
conn = sqlite3.connect('weather.db')
cursor = conn.cursor()

def extract_load(links):

    cursor.executescript('''

            CREATE TABLE IF NOT EXISTS weather (
                     lat,
                     lon,
                     timezone,
                     timezone_offset,
                     date_time,
                     sunrise,
                     sunset,
                     temp,
                     feels_like,
                     pressure,
                     humidity,
                     dew_point,
                     uvi,
                     clouds,
                     visibility,
                     wind_speed,
                     wind_gust,
                     wind_deg,
                     weather_id,
                     main,
                     description,
                     icon,
                     rain,
                     snow     
            )
        ''')

    for link in links:

        response = requests.get(link)

        data = clean_data(response.json())

        cursor.execute('''INSERT INTO weather VALUES (:lat, :lon, :timezone, :timezone_offset,
                       :dt, :sunrise, :sunset, :temp, :feels_like, :pressure, :humidity, 
                       :dew_point, :uvi, :clouds, :visibility, :wind_speed, :wind_gust, :wind_deg, 
                       :id, :main, :description, :icon, :rain, :snow)''', data
                       )
        
        conn.commit()

# %% [markdown]
# Testing

# %%
#drop_table()

extract_load(get_links())

# %%
df = pd.read_sql_query('''SELECT * FROM weather''', conn)
df
# Out:
#          lat     lon       timezone  timezone_offset   date_time     sunrise  \
# 0    51.5072  0.1276  Europe/London                0  1705345200  1705305532
# 1    51.5072  0.1276  Europe/London                0  1705348800  1705305532
# 2    51.5072  0.1276  Europe/London                0  1705352400  1705305532
# 3    51.5072  0.1276  Europe/London                0  1705356000  1705305532
# 4    51.5072  0.1276  Europe/London                0  1705359600  1705305532
# ..       ...     ...            ...              ...         ...         ...
# 944  51.5072  0.1276  Europe/London                0  1708743600  1708757816
# 945  51.5072  0.1276  Europe/London                0  1708747200  1708757816
# 946  51.5072  0.1276  Europe/London                0  1708750800  1708757816
# 947  51.5072  0.1276  Europe/London                0  1708754400  1708757816
# 948  51.5072  0.1276  Europe/London                0  1708758000  1708757816
#
#          sunset  temp  feels_like  pressure  ...  visibility  wind_speed  \
# 0    1705335481  0.18       -3.36      1012  ...       10000        3.09
# 1    1705335481  0.11       -1.69      1012  ...       10000        1.54
# 2    1705335481 -0.20       -3.33      1012  ...       10000        2.57
# 3    1705335481 -0.61       -4.31      1012  ...       10000        3.09
# 4    1705335481 -1.30       -4.05      1012  ...       10000        2.06
# ..          ...   ...         ...       ...  ...         ...         ...
# 944  1708795741  2.07       -0.11       991  ...       10000        2.06
# 945  1708795741  1.40       -0.90       991  ...       10000        2.06
# 946  1708795741  1.22       -1.65       992  ...       10000        2.57
# 947  1708795741  1.09       -0.57       992  ...       10000        1.54
# 948  1708795741  1.08       -1.81       993  ...       10000        2.57
#
#     wind_gust  wind_deg weather_id    main       description  icon  rain snow
# 0         N/A       290        801  Clouds        few clouds   02n   N/A  N/A
# 1         N/A       290        801  Clouds        few clouds   02n   N/A  N/A
# 2         N/A       290        803  Clouds     broken clouds   04n   N/A  N/A
# 3         N/A       280        803  Clouds     broken clouds   04n   N/A  N/A
# 4         N/A       250        803  Clouds     broken clouds   04n   N/A  N/A
# ..        ...       ...        ...     ...               ...   ...   ...  ...
# 944       N/A       220        804  Clouds   overcast clouds   04n   N/A  N/A
# 945       N/A       220        803  Clouds     broken clouds   04n   N/A  N/A
# 946       N/A       230        803  Clouds     broken clouds   04n   N/A  N/A
# 947       N/A       210        802  Clouds  scattered clouds   03n   N/A  N/A
# 948       N/A       230        800   Clear         clear sky   01d   N/A  N/A
#
# [949 rows x 24 columns]

# %% [markdown]
# First plot

# %%
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource

def plot_temp_feels_like(data):

    source = ColumnDataSource(data)

    p = figure(x_axis_label=r'\[\text{ Temperature }^\circ C\]',
               y_axis_label=r'\[\text{ Feels like temp }^\circ C\]')

    p.circle(x='temp',
             y='feels_like', source=source, fill_color='blue')

    show(p)

plot_temp_feels_like(df)

# %%
def plot_temp_pressure(data):

    source = ColumnDataSource(data)

    p = figure(x_axis_label=r'\[\text{ Temperature }^\circ C\]',
               y_axis_label=r'\[\text{ Pressure }hPa\]')

    p.circle(x='temp',
             y='pressure', source=source, fill_color='blue')

    show(p)

plot_temp_pressure(df)

# %%
def plot_wind_s_d(data):
 
    source = ColumnDataSource(data)

    p = figure(x_axis_label=r'\[\text{ Wind Direction }\]',
                y_axis_label=r'\[\text{ Wind Speed }ms^{-1}\]')

    p.circle(x='wind_deg',
            y='wind_speed', source=source, fill_color='blue')

    show(p)

plot_wind_s_d(df)

# %%
def load_old_data():
     df = read_sql_query('''SELECT * FROM weather''', conn)
     first_date = df['date_time'][0]
     old_date = first_date - 3600 * 950
     return old_date

load_old_data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       4      old_date = first_date - 3600 * 950
#       5      return old_date
# ----> 7 load_old_data()
#
# Cell In[1], line 2, in load_old_data()
#       1 def load_old_data():
# ----> 2      df.read_sql_query('''SELECT * FROM weather''', conn)
#       3      first_date = df['date_time'][0]
#       4      old_date = first_date - 3600 * 950
#
# NameError: name 'df' is not defined

# %% [markdown]
# Code so far - run from here to avoid issues

# %%
import requests
import sqlite3
import time
import pandas as pd
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource


conn = sqlite3.connect('weather.db')
cursor = conn.cursor()


def last_executed():

        try:
                with open('last_executed.txt') as f:
                        last_execution_date = int(f.read())
        except FileNotFoundError:
                last_execution_date = int(time.time())

        return last_execution_date


def update_executed():
    with open('last_executed.txt', 'w') as f:
        f.write(str(int(time.time())))


def get_links(last_execution_date):

    if last_execution_date // 86400 ==  time.time() // 86400:
        return []

    links = []

    def build_link(date):
        lat = '51.5072'
        lon = '0.1276'
        from key import key
        link = f'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat={lat}&lon={lon}&dt={date}&appid={key}&units=metric'
        links.append(link)

    nearest_hour = int(time.time() - time.time() % 3600)
    nearest_hour_old = last_execution_date - last_execution_date % 3600

    for x in range(nearest_hour_old, nearest_hour, 3600):
        build_link(x)
    
    return links


def get_links_past(x):

    links = []

    def build_link(date):
        lat = '51.5072'
        lon = '0.1276'
        from key import key
        link = f'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat={lat}&lon={lon}&dt={date}&appid={key}&units=metric'
        links.append(link)

    df = pd.read_sql_query('''SELECT date_time FROM weather''', conn)
    first_date = df['date_time'].min()
    past_date = first_date - 3600 * x

    for x in range(past_date, first_date, 3600):
        build_link(x)
    
    return links


def clean_data(data):

    d1 = {
         'lat': data['lat'],
         'lon': data['lon'],
         'timezone': data['timezone'],
         'timezone_offset': data['timezone_offset']
          }

    for i in data['data']:
        d1.update(i)

    for i in d1['weather']:
        d1.update(i)

    d1.pop('weather')

    data = d1

    if 'rain' in data.keys():
        data['rain'] = [*data['rain'].values()][0]

    if 'snow' in data.keys():
        data['snow'] = [*data['snow'].values()][0]

    all_api_keys = [
         'lat', 'lon', 'timezone', 'timezone_offset', 'dt', 
         'sunrise', 'sunset', 'temp', 'feels_like', 'pressure', 
         'humidity', 'dew_point', 'uvi', 'clouds', 'visibility', 
         'wind_speed', 'wind_deg', 'wind_gust', 'id', 'main', 
         'description', 'icon', 'rain', 'snow'
                    ]
    
    for i in all_api_keys:
        if i not in data.keys():
            i = {i: 'N/A'}
            data.update(i)

    return data


def extract_load(links):

    cursor.executescript('''

            CREATE TABLE IF NOT EXISTS weather (
                     lat,
                     lon,
                     timezone,
                     timezone_offset,
                     date_time,
                     sunrise,
                     sunset,
                     temp,
                     feels_like,
                     pressure,
                     humidity,
                     dew_point,
                     uvi,
                     clouds,
                     visibility,
                     wind_speed,
                     wind_gust,
                     wind_deg,
                     weather_id,
                     main,
                     description,
                     icon,
                     rain,
                     snow     
            )
        ''')

    for link in links:

        response = requests.get(link)

        data = clean_data(response.json())

        cursor.execute('''INSERT INTO weather VALUES (:lat, :lon, :timezone, :timezone_offset,
                       :dt, :sunrise, :sunset, :temp, :feels_like, :pressure, :humidity, 
                       :dew_point, :uvi, :clouds, :visibility, :wind_speed, :wind_gust, :wind_deg, 
                       :id, :main, :description, :icon, :rain, :snow)''', data
                       )
        
        conn.commit()


def plot_temp_feels_like(data):

    source = ColumnDataSource(data)

    p = figure(x_axis_label=r'\[\text{ Temperature }^\circ C\]',
               y_axis_label=r'\[\text{ Feels like temp }^\circ C\]')

    p.circle(x='temp',
             y='feels_like', source=source, fill_color='blue')

    show(p)


def plot_temp_pressure(data):

    source = ColumnDataSource(data)

    p = figure(x_axis_label=r'\[\text{ Temperature }^\circ C\]',
               y_axis_label=r'\[\text{ Pressure }hPa\]')

    p.circle(x='temp',
             y='pressure', source=source, fill_color='blue')

    show(p)


def plot_wind_s_d(data):
 
    source = ColumnDataSource(data)

    p = figure(x_axis_label=r'\[\text{ Wind Direction }\]',
               y_axis_label=r'\[\text{ Wind Speed }ms^{-1}\]')

    p.circle(x='wind_deg',
             y='wind_speed', source=source, fill_color='blue')

    show(p)

def plot_temp_humidity(data):
 
    source = ColumnDataSource(data)

    p = figure(x_axis_label=r'\[\text{ Temperature }^\circ C\]',
               y_axis_label=r'\[\text{ Humidity }\%\]')

    p.circle(x='temp',
             y='humidity', source=source, fill_color='blue')

    #p.circle(x='feels_like',
             #y='humidity', source=source, fill_color='green')
    
    show(p)

# %%
extract_load(get_links_past(900))

# %%
extract_load(get_links(last_executed()))

# %%
update_executed()

# %%
df[df.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [index, lat, lon, timezone, timezone_offset, date_time, sunrise, sunset, temp, feels_like, pressure, humidity, dew_point, uvi, clouds, visibility, wind_speed, wind_gust, wind_deg, weather_id, main, description, icon, rain, snow]
# Index: []
#
# [0 rows x 25 columns]

# %%
df = pd.read_sql_query('''SELECT * FROM weather''', conn)
df = df.sort_values('date_time').reset_index()
df.head(10)
# Out:
#    index      lat     lon       timezone  timezone_offset   date_time  \
# 0   7713  51.5072  0.1276  Europe/London                0  1676548800
# 1   7714  51.5072  0.1276  Europe/London                0  1676552400
# 2   7715  51.5072  0.1276  Europe/London                0  1676556000
# 3   7716  51.5072  0.1276  Europe/London                0  1676559600
# 4   7717  51.5072  0.1276  Europe/London                0  1676563200
# 5   7718  51.5072  0.1276  Europe/London                0  1676566800
# 6   7719  51.5072  0.1276  Europe/London                0  1676570400
# 7   7720  51.5072  0.1276  Europe/London                0  1676574000
# 8   7721  51.5072  0.1276  Europe/London                0  1676577600
# 9   7722  51.5072  0.1276  Europe/London                0  1676581200
#
#       sunrise      sunset   temp  feels_like  ...  visibility  wind_speed  \
# 0  1676531547  1676567699  11.24       10.69  ...       10000        4.63
# 1  1676531547  1676567699  11.50       10.98  ...       10000        5.14
# 2  1676531547  1676567699  12.01       11.56  ...       10000        4.63
# 3  1676531547  1676567699  12.01       11.59  ...       10000        4.12
# 4  1676531547  1676567699  12.67       12.21  ...       10000        3.60
# 5  1676531547  1676567699  12.97       12.46  ...       10000        5.14
# 6  1676531547  1676567699  12.12       11.66  ...       10000        5.14
# 7  1676531547  1676567699  11.84       11.38  ...       10000        4.63
# 8  1676531547  1676567699  11.73       11.18  ...       10000        5.70
# 9  1676531547  1676567699  10.96       10.33  ...       10000        5.14
#
#    wind_gust wind_deg  weather_id    main      description icon  rain  snow
# 0        N/A      230         804  Clouds  overcast clouds  04d   N/A   N/A
# 1        N/A      220         804  Clouds  overcast clouds  04d   N/A   N/A
# 2        N/A      240         804  Clouds  overcast clouds  04d   N/A   N/A
# 3        N/A      240         804  Clouds  overcast clouds  04d   N/A   N/A
# 4        N/A      240         804  Clouds  overcast clouds  04d   N/A   N/A
# 5        N/A      250         803  Clouds    broken clouds  04d   N/A   N/A
# 6        N/A      250         500    Rain       light rain  10n   0.1   N/A
# 7        N/A      240         803  Clouds    broken clouds  04n   N/A   N/A
# 8          0      250         801  Clouds       few clouds  02n   N/A   N/A
# 9        N/A      240         800   Clear        clear sky  01n   N/A   N/A
#
# [10 rows x 25 columns]

# %%
df.corr()
# Out:
# C:\Users\Jack\AppData\Local\Temp\ipykernel_18524\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                     index  lat  lon  timezone_offset  date_time   sunrise  \
# index            1.000000  NaN  NaN         0.414326  -0.875671 -0.875694
# lat                   NaN  NaN  NaN              NaN        NaN       NaN
# lon                   NaN  NaN  NaN              NaN        NaN       NaN
# timezone_offset  0.414326  NaN  NaN         1.000000  -0.533801 -0.533972
# date_time       -0.875671  NaN  NaN        -0.533801   1.000000  0.999997
# sunrise         -0.875694  NaN  NaN        -0.533972   0.999997  1.000000
# sunset          -0.875650  NaN  NaN        -0.533376   0.999997  1.000000
# temp             0.105886  NaN  NaN         0.668725  -0.225820 -0.226444
# feels_like       0.106502  NaN  NaN         0.674619  -0.229126 -0.229710
# pressure         0.133359  NaN  NaN         0.211765  -0.186138 -0.186136
# humidity        -0.148398  NaN  NaN        -0.354455   0.203979  0.204895
# dew_point        0.041644  NaN  NaN         0.601970  -0.155604 -0.155850
# clouds          -0.035595  NaN  NaN        -0.173006   0.080370  0.080508
# wind_speed      -0.094326  NaN  NaN        -0.107549   0.071488  0.071053
# wind_deg        -0.189763  NaN  NaN        -0.135553   0.128266  0.128308
# weather_id      -0.017542  NaN  NaN         0.073032   0.007170  0.007207
#
#                    sunset      temp  feels_like  pressure  humidity  \
# index           -0.875650  0.105886    0.106502  0.133359 -0.148398
# lat                   NaN       NaN         NaN       NaN       NaN
# lon                   NaN       NaN         NaN       NaN       NaN
# timezone_offset -0.533376  0.668725    0.674619  0.211765 -0.354455
# date_time        0.999997 -0.225820   -0.229126 -0.186138  0.203979
# sunrise          1.000000 -0.226444   -0.229710 -0.186136  0.204895
# sunset           1.000000 -0.225898   -0.229163 -0.186069  0.204629
# temp            -0.225898  1.000000    0.993246  0.045309 -0.547242
# feels_like      -0.229163  0.993246    1.000000  0.044803 -0.503351
# pressure        -0.186069  0.045309    0.044803  1.000000 -0.237650
# humidity         0.204629 -0.547242   -0.503351 -0.237650  1.000000
# dew_point       -0.155348  0.882717    0.899898 -0.068967 -0.095503
# clouds           0.080394 -0.129090   -0.118448 -0.058208  0.259905
# wind_speed       0.071004  0.179057    0.136199 -0.189009 -0.241240
# wind_deg         0.128213  0.006981   -0.001363 -0.169042  0.031362
# weather_id       0.007289  0.040641    0.038729  0.371107 -0.270172
#
#                  dew_point    clouds  wind_speed  wind_deg  weather_id
# index             0.041644 -0.035595   -0.094326 -0.189763   -0.017542
# lat                    NaN       NaN         NaN       NaN         NaN
# lon                    NaN       NaN         NaN       NaN         NaN
# timezone_offset   0.601970 -0.173006   -0.107549 -0.135553    0.073032
# date_time        -0.155604  0.080370    0.071488  0.128266    0.007170
# sunrise          -0.155850  0.080508    0.071053  0.128308    0.007207
# sunset           -0.155348  0.080394    0.071004  0.128213    0.007289
# temp              0.882717 -0.129090    0.179057  0.006981    0.040641
# feels_like        0.899898 -0.118448    0.136199 -0.001363    0.038729
# pressure         -0.068967 -0.058208   -0.189009 -0.169042    0.371107
# humidity         -0.095503  0.259905   -0.241240  0.031362   -0.270172
# dew_point         1.000000 -0.014250    0.087170  0.031373   -0.092493
# clouds           -0.014250  1.000000    0.010282  0.040990   -0.168198
# wind_speed        0.087170  0.010282    1.000000  0.217338   -0.092615
# wind_deg          0.031373  0.040990    0.217338  1.000000   -0.034409
# weather_id       -0.092493 -0.168198   -0.092615 -0.034409    1.000000

# %%
plot_temp_feels_like(df)
plot_temp_pressure(df)
plot_wind_s_d(df)
plot_temp_humidity(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4862 entries, 0 to 4861
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            4862 non-null   int64
#  1   lat              4862 non-null   float64
#  2   lon              4862 non-null   float64
#  3   timezone         4862 non-null   object
#  4   timezone_offset  4862 non-null   int64
#  5   date_time        4862 non-null   int64
#  6   sunrise          4862 non-null   int64
#  7   sunset           4862 non-null   int64
#  8   temp             4862 non-null   float64
#  9   feels_like       4862 non-null   float64
#  10  pressure         4862 non-null   int64
#  11  humidity         4862 non-null   int64
#  12  dew_point        4862 non-null   float64
#  13  uvi              4862 non-null   object
#  14  clouds           4862 non-null   int64
#  15  visibility       4862 non-null   object
#  16  wind_speed       4862 non-null   float64
#  17  wind_gust        4862 non-null   object
#  18  wind_deg         4862 non-null   int64
#  19  weather_id       4862 non-null   int64
#  20  main             4862 non-null   object
#  21  description      4862 non-null   object
#  22  icon             4862 non-null   object
#  23  rain             4862 non-null   object
#  24  snow             4862 non-null   object
# dtypes: float64(6), int64(10), object(9)
# memory usage: 949.7+ KB

# %%
def build_link_mistake(date):
    lat = '51.5072'
    lon = '0.1276'
    from python.key import key
    link = f'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat={lat}&lon={lon}&dt={date}&appid={key}&units=metric'

    return link

link_mistake = build_link_mistake(1708966800)

# %%
response = requests.get(link_mistake)

data_mistake = clean_data(response.json())

data_mistake
# Out:
# {'lat': 51.5072,
#  'lon': 0.1276,
#  'timezone': 'Europe/London',
#  'timezone_offset': 0,
#  'dt': 1708966800,
#  'sunrise': 1708930365,
#  'sunset': 1708968756,
#  'temp': 7.75,
#  'feels_like': 4.72,
#  'pressure': 1014,
#  'humidity': 63,
#  'dew_point': 1.16,
#  'uvi': 0,
#  'clouds': 20,
#  'visibility': 10000,
#  'wind_speed': 5.14,
#  'wind_deg': 30,
#  'wind_gust': 12.35,
#  'id': 801,
#  'main': 'Clouds',
#  'description': 'few clouds',
#  'icon': '02d',
#  'rain': 'N/A',
#  'snow': 'N/A'}

# %%
cursor.execute('''INSERT INTO weather VALUES (:lat, :lon, :timezone, :timezone_offset,
                :dt, :sunrise, :sunset, :temp, :feels_like, :pressure, :humidity, 
                :dew_point, :uvi, :clouds, :visibility, :wind_speed, :wind_gust, :wind_deg, 
                :id, :main, :description, :icon, :rain, :snow)''', data_mistake
                )

conn.commit()

# %%
from datetime import datetime

datetime.utcfromtimestamp(last_execution_date).strftime('%Y-%m-%dT%H:%M:%SZ')
# Out:
# '2024-02-24T09:51:01Z'

# %% [markdown]
# Changing from SQLite to MySQL

# %%
import mysql.connector
#from key import sql_pass

db = mysql.connector.connect(
    host='localhost',
    user='root',
    passwd='DYxKavh#4S29%SQqQj&@',
    database='test'
)
cursor = db.cursor()

# %%
import requests
import mysql.connector
import time
import pandas as pd
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource
#from key import sql_pass
from key import key


db = mysql.connector.connect(
    host='localhost',
    user='root',
    passwd='DYxKavh#4S29%SQqQj&@',
    database='test'
)
cursor = db.cursor()


def last_executed():

        try:
                with open('last_executed.txt') as f:
                        last_execution_date = int(f.read())
        except FileNotFoundError:
                last_execution_date = int(time.time())

        return last_execution_date


def update_executed():
    with open('last_executed.txt', 'w') as f:
        f.write(str(int(time.time())))


def get_links(last_execution_date):

    if last_execution_date // 86400 ==  time.time() // 86400:
        return []

    links = []

    def build_link(date):
        lat = '51.5072'
        lon = '0.1276'
        link = f'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat={lat}&lon={lon}&dt={date}&appid={key}&units=metric'
        links.append(link)

    nearest_hour = int(time.time() - time.time() % 3600)
    nearest_hour_old = last_execution_date - last_execution_date % 3600

    for x in range(nearest_hour_old, nearest_hour, 3600):
        build_link(x)
    
    return links


def get_links_past(x):

    links = []

    def build_link(date):
        lat = '51.5072'
        lon = '0.1276'
        from python.key import key
        link = f'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat={lat}&lon={lon}&dt={date}&appid={key}&units=metric'
        links.append(link)

    df = pd.read_sql_query('''SELECT date_time FROM weather''', db)
    first_date = df['date_time'].min()
    past_date = first_date - 3600 * x

    for x in range(past_date, first_date, 3600):
        build_link(x)
    
    return links


def clean_data(data):

    d1 = {
         'lat': data['lat'],
         'lon': data['lon'],
         'timezone': data['timezone'],
         'timezone_offset': data['timezone_offset']
          }

    for i in data['data']:
        d1.update(i)

    for i in d1['weather']:
        d1.update(i)

    d1.pop('weather')

    data = d1

    if 'rain' in data.keys():
        data['rain'] = [*data['rain'].values()][0]

    if 'snow' in data.keys():
        data['snow'] = [*data['snow'].values()][0]

    all_api_keys = [
         'lat', 'lon', 'timezone', 'timezone_offset', 'dt', 
         'sunrise', 'sunset', 'temp', 'feels_like', 'pressure', 
         'humidity', 'dew_point', 'uvi', 'clouds', 'visibility', 
         'wind_speed', 'wind_deg', 'wind_gust', 'id', 'main', 
         'description', 'icon', 'rain', 'snow'
                    ]
    
    for i in all_api_keys:
        if i not in data.keys():
            i = {i: 'N/A'}
            data.update(i)

    return data


def extract_load(links):

    cursor.execute('''

            CREATE TABLE IF NOT EXISTS weather (
                     lat FLOAT(4),
                     lon FLOAT(4),
                     timezone VARCHAR(15),
                     timezone_offset INT(3),
                     dt INT(15),
                     sunrise INT(15),
                     sunset INT(15),
                     temp FLOAT(2),
                     feels_like FLOAT(2),
                     pressure INT(4),
                     humidity INT(3),
                     dew_point FLOAT(2),
                     uvi INT(2),
                     clouds INT(3),
                     visibility INT(5),
                     wind_speed FLOAT(2),
                     wind_gust FLOAT(2),
                     wind_deg INT(3),
                     weather_id INT(3),
                     main VARCHAR(20),
                     description VARCHAR(30),
                     icon VARCHAR(3),
                     rain FLOAT(2),
                     snow FLOAT(2)     
            )
        ''')

    for link in links:

        response = requests.get(link)

        data = clean_data(response.json())
        placeholders = ', '.join(['%s']) * len(data)
        columns = ', '.join(data.keys())
        sql = f"INSERT INTO weather {columns} VALUES {placeholders}"
        cursor.execute(sql, list(data.values()))
        
        #cursor.execute('''INSERT INTO weather (lat,lon,timezone,timezone_offset,
                       #date_time,sunrise,sunset,temp,feels_like,pressure,humidity,
                      # dew_point,uvi,clouds,visibility,wind_speed,wind_gust,
                      # wind_deg,weather_id,main,description,icon,rain,snow) 
                      # VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,
                       #%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)''', values
                      # )
        
        db.commit()


def plot_temp_feels_like(data):

    source = ColumnDataSource(data)

    p = figure(x_axis_label=r'\[\text{ Temperature }^\circ C\]',
               y_axis_label=r'\[\text{ Feels like temp }^\circ C\]')

    p.circle(x='temp',
             y='feels_like', source=source, fill_color='blue')

    show(p)


def plot_temp_pressure(data):

    source = ColumnDataSource(data)

    p = figure(x_axis_label=r'\[\text{ Temperature }^\circ C\]',
               y_axis_label=r'\[\text{ Pressure }hPa\]')

    p.circle(x='temp',
             y='pressure', source=source, fill_color='blue')

    show(p)


def plot_wind_s_d(data):
 
    source = ColumnDataSource(data)

    p = figure(x_axis_label=r'\[\text{ Wind Direction }\]',
               y_axis_label=r'\[\text{ Wind Speed }ms^{-1}\]')

    p.circle(x='wind_deg',
             y='wind_speed', source=source, fill_color='blue')

    show(p)

def plot_temp_humidity(data):
 
    source = ColumnDataSource(data)

    p = figure(x_axis_label=r'\[\text{ Temperature }^\circ C\]',
               y_axis_label=r'\[\text{ Humidity }\%\]')

    p.circle(x='temp',
             y='humidity', source=source, fill_color='blue')

    #p.circle(x='feels_like',
             #y='humidity', source=source, fill_color='green')
    
    show(p)

# %%
extract_load(get_links(last_executed()))
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\Jack\AppData\Local\Programs\Python\Python311\Lib\site-packages\mysql\connector\connection_cext.py:661, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     660         query = query.encode("utf-8")
# --> 661     self._cmysql.query(
#     662         query,
#     663         raw=raw,
#     664         buffered=buffered,
#     665         raw_as_string=raw_as_string,
#     666         query_attrs=self.query_attrs,
#     667     )
#     668 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'lat, lon, timezone, timezone_offset, dt, sunrise, sunset, temp, feels_like, pres' at line 1
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 extract_load(get_links(last_executed()))
#
# Cell In[47], line 160, in extract_load(links)
#     158 columns = ', '.join(data.keys())
#     159 sql = f"INSERT INTO weather {columns} VALUES {placeholders}"
# --> 160 cursor.execute(sql, list(data.values()))
#     162 #cursor.execute('''INSERT INTO weather (lat,lon,timezone,timezone_offset,
#     163                #date_time,sunrise,sunset,temp,feels_like,pressure,humidity,
#     164               # dew_point,uvi,clouds,visibility,wind_speed,wind_gust,
#    (...)
#     167                #%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)''', values
#     168               # )
#     170 db.commit()
#
# File c:\Users\Jack\AppData\Local\Programs\Python\Python311\Lib\site-packages\mysql\connector\cursor_cext.py:374, in CMySQLCursor.execute(self, operation, params, multi)
#     369             raise ProgrammingError(
#     370                 "Not all parameters were used in the SQL statement"
#     371             )
#     373 try:
# --> 374     result = self._cnx.cmd_query(
#     375         stmt,
#     376         raw=self._raw,
#     377         buffered=self._buffered,
#     378         raw_as_string=self._raw_as_string,
#     379     )
#     380 except MySQLInterfaceError as err:
#     381     raise get_mysql_exception(
#     382         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     383     ) from err
#
# File c:\Users\Jack\AppData\Local\Programs\Python\Python311\Lib\site-packages\mysql\connector\opentelemetry\context_propagation.py:74, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      72 """Context propagation decorator."""
#      73 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 74     return method(cnx, *args, **kwargs)
#      76 current_span = trace.get_current_span()
#      77 tp_header = None
#
# File c:\Users\Jack\AppData\Local\Programs\Python\Python311\Lib\site-packages\mysql\connector\connection_cext.py:669, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     661     self._cmysql.query(
#     662         query,
#     663         raw=raw,
#    (...)
#     666         query_attrs=self.query_attrs,
#     667     )
#     668 except MySQLInterfaceError as err:
# --> 669     raise get_mysql_exception(
#     670         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     671     ) from err
#     672 except AttributeError as err:
#     673     addr = (
#     674         self._unix_socket if self._unix_socket else f"{self._host}:{self._port}"
#     675     )
#
# ProgrammingError: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'lat, lon, timezone, timezone_offset, dt, sunrise, sunset, temp, feels_like, pres' at line 1
